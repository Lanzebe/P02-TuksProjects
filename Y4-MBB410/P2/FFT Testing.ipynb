# %%
import matplotlib.pyplot as plt

# %matplotlib notebook
import numpy as np
from scipy.fft import fft, fftshift, fftfreq
from scipy.signal import windows as win

# %%
fs = 2000


xs = np.arange(0, 10 + 1/(fs), 1/(fs))
print(len(xs))

hw = win.cosine(len(xs))

NumOfSines = 10


freq = np.random.uniform(low=0.1, high=50, size=(NumOfSines,))  #[1/3,2**0.5]
ampl = np.random.uniform(low=0.1, high=5, size=(NumOfSines,))

print('Frequencies:',freq)
print('Amplitudes:',ampl)

ys = np.sum(np.multiply(ampl,(np.sin(np.multiply(freq,np.transpose([2*np.pi*xs]*len(freq)))))),axis = 1)

plt.figure(1)
plt.plot(xs,ys)
plt.plot(xs,ys*hw)
plt.grid()
plt.show()
# Out:
# 20001
# Frequencies: [49.65221032 10.41239173 49.09782991 11.2995416  13.32469038 16.58313496
#  43.24445739 18.31534673 28.54121252 44.79149293]
# Amplitudes: [1.60972218 3.83276713 2.37165685 3.13991857 4.78104719 3.35207978
#  2.21292927 2.12748445 3.28828553 2.5837536 ]
# <img src="data:image/png;base64,..." width="640">

# %%
out=fft(ys)

fv=fftfreq(len(xs),1/fs)

fig,axs=plt.subplots(2)

axs[0].plot(abs(out))
axs[1].plot(fv)
sp=fftshift(out)*2/len(xs)  ### scalling to the right amplitudes
freq=fftshift(fv)
plt.figure()
plt.plot(freq,abs(sp))
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
