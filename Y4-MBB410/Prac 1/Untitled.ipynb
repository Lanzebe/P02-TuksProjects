# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %%
a = [0,1,0,1,0,1,0,1]
b = [0,0,0,0,1,1,1,1]

plt.figure()
plt.plot(a)
plt.plot(b)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(np.logical_and(a, b))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
