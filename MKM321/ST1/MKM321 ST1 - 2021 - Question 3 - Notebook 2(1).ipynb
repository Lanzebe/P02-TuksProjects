# %% [markdown]
# *Surnmame and Initials*
#
# *Student Number*
#
# ### Semester Test 1 MKM321 Full marks [45]
# -----------
# ### Duration: 90 minutes (90 minutes of writing and 15 minutes to upload and complete the ClickUP test)
# ### Allowable Material: Prescribed Textbook and material available on ClickUP.
# ### Questions 1 - 3
# ### For Questions 2-3, grades are only awarded for the rationale, reasoning, methodology or evidence that backup the answer.
# ### All questions must also be answered on ClickUP which includes uploading this notebook and filling in the multiple choice questions.
# ---------
#
# ### Integrity Statement
#
# ### The University of Pretoria commits itself to produce academic work of integrity. I affirm that I am aware of and have read the Rules and Policies of the University, more specifically the Disciplinary Procedure and the Tests and Examinations Rules, which prohibit any unethical, dishonest or improper conduct during tests, assignments, examinations and/or any other forms of assessment. I am aware that no student or any other person may assist or attempt to assist another student, or obtain help, or attempt to obtain help from another student or any other person during tests, assessments, assignments, examinations and/or any other forms of assessment.
# ------------------------------------

# %% [markdown]
# # Question 3 [Full Marks 15]
# ## Given below are claimed solutions to the stated problem. In your motivations include qualitative and quantitative motivations.
# ## In this section only state motivations that you are certain of. Wrong motivations will be graded negatively. No beam deflection equation tables are required when answering this question. All observations and quantifications must be clearly motivated.
#
# ## Consider the problem depicted below.  L = 0.5m. The beam is made of steel E = 210 GPa, with rectangular cross sectional area of height 200mm and width 150mm. $P=2$kN.

# %%
from IPython.display import Image
Image('question3_2021.jpg',embed=True)

# %%
from IPython.display import Image
Image('q31.png',embed=True)

# %%
from IPython.display import Image
Image('q32.png',embed=True)

# %%
from IPython.display import Image
Image('q33.png',embed=True)

# %%
from IPython.display import Image
Image('q34.png',embed=True)

# %%
from IPython.display import Image
Image('q35.png',embed=True)

# %% [markdown]
# ## 3.1. Critically evaluate the given vertical displacement field i.e. highlight all aspects that you deem consistent and all aspects you deem inconsistent w.r.t. the stated problem [3].
# ### Example: Consistent: displacement is downwards as expected [1]

# %% [markdown]
# ------ ANSWER HERE (Double Click This Cell) -------
# The displacements at x=0, x=L and x=4L must be zero as this is where the support are. Plot is consistent.
# There is no loading between 0<x>L and the support at x=L is fixed. Thus no displacement between these points. Plot is consistent.
# The loads P are both downward. Thus the beam deflection must only be downward. Plot is consistent.

# %% [markdown]
# ## 3.2 Critically evaluate the given first derivative field $\frac{dv}{dx}$ i.e. highlight all aspects that you deem consistent and all aspects you deem inconsistent w.r.t. the stated problem. [3]

# %% [markdown]
# ------ ANSWER HERE (Double Click This Cell) -------
# dv/dx implies angle of the beam.
# Angle at x=L must be zero as it is a fixed support. Additionaly the angle form x=0 to x=L must also be 0 as there is no deflection in this region. Plot is consistent.
# There is a position were the angle of the beam must be 0 between 1.25<x>1.5m as this is the turning point of the deflection. Plot is consistent.
# Bending moment must become positive between 0.75<x>1. As the angle reaches a maximum. The graph does cross the x axis and is therfore consistent.

# %% [markdown]
# ## 3.3 Critically evaluate the given second derivative field $\frac{d^2v}{dx^2}$ i.e. highlight aspects that are consistent and inconsistent w.r.t. the stated problem. [3]

# %% [markdown]
# ------ ANSWER HERE (Double Click This Cell) -------
# if d2v/dx2 is multiplied by EI it coresponds to the Beanding moment.
# Firstly the beam must be in equilibrium and there is no momenet applied to the end of the beam at x=4L. So the plot must end at a magnitude of 0. Plot is therfore consistent.
# Addidionaly there is no loading between 0<x>L and it has fixed supports. so no moment in this region. Plot is consistent.
# At x=L there must be a counter-clockwise moment to counter the moments produced by the loads. And this transfers to a negative moment onto the graph of d2v/dx2. Plot is consistent.
# Form the graph it looks like the maximum BM at x=L is -0.00026*E*I= 5460 N/m. Not enough time to analyse magnitudes. Plot may still be inconsistent.

# %%
E= 210e9
I = (0.15*0.2**3)/12
print(-0.00026*E*I)
# Out:
# -5460.000000000001

# %% [markdown]
# ## 3.4. Critically evaluate the given third derivative field $\frac{d^3v}{dx^3}$ i.e. highlight aspects that are consistent and inconsistent w.r.t. the stated problem. Include a quantitative evaluation as well, i.e. are the numbers correct? [3]

# %% [markdown]
# ------ ANSWER HERE (Double Click This Cell) -------
# d3v/dx3*E*I coresponds to the Shear force in a beam.
# Form inspection the graph does coresspond to the gradient of the d2v/dx2 plot. Plot is consistent.
# The shear force between 0<x>L must be 0 N.Plot is consistent.
# Additionaly the gaps between the horisontal lines must correspond to the magnitudes by gap*E*I=P. From graph p = 9450. P actual == 2000. So Graph is inconsistent in magnitude but in the right shape

# %%
print('gap:',(0.00065-0.0002)*E*I)
# Out:
# gap: 9450.000000000004

# %% [markdown]
# ## 3.5. Critically evaluate the given fourth derivative field $\frac{d^4v}{dx^4}$ i.e. highlight aspects that are consistent and inconsistent w.r.t. the stated problem. Critically interpret the implication of the provided result? [3]

# %% [markdown]
# ------ ANSWER HERE (Double Click This Cell) -------
# d4v/dx4*E*I coresponds to the applied Distributed loading of the beam
# As the beam experiences on distributed loads it must be 0 allong the whole lenght of the beam. Plot is consistent.
