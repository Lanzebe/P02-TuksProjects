# %% [markdown]
# # Verification & Validation (NAFEMS)
# ## What is Verification?
# ## *"The process of determining that a computational model accurately represents the underlying mathematical model and its solution."* [NAFEMS V&V https://www.nafems.org/publications/browse_buy/browse_by_topic/qa/verification_and_validation/]
# ## What is Validation?
# ## *"The process of determining the degree to which a model is an accurate representation of the real world from the perspective of the intended uses of the model."* [NAFEMS V&V https://www.nafems.org/publications/browse_buy/browse_by_topic/qa/verification_and_validation/]
# ## MRN412 & MRN422 - VALIDATION is an essential outcome
#
# ## Photostress for Validation: https://www.youtube.com/watch?v=BdSaA9byKms
# ## Photoleasticity overview video: https://youtu.be/uaH7HSDI10w
# ## Photoelasticity DIY: https://www.youtube.com/watch?v=8rtts66THp0
#
# ##
#
# ## Photoelasticity (Plane stress measurement $\sigma_3=0$)
# ## Isoclinics
# ### Isoclinics are black fringes that join all points with the same principal stress directions are the same
# $$\tilde{\tau}_{xy} =(\sigma_{yy}-\sigma_{xx})\sin\theta\cos\theta + \tau_{xy}(cos^2\theta - sin^2\theta)$$
# ### Principal stress orientation $\theta_P$, occurs when $\tilde{\tau}_{xy} = 0,$, hence
# $$0 =(\sigma_{yy}-\sigma_{xx})\sin\theta_P\cos\theta_P + \tau_{xy}(cos^2\theta_P - sin^2\theta_P)$$
#
# $$\tan(2\theta_P) = \frac{2\tau_{xy}}{\sigma_{xx}-\sigma_{yy}}$$
# ## Isochromatics
# ### Isochromatics are lines of constant colour when a white light source are used. The colours are related to the level of loading, specifically contours of constant principal stress. Stress-optic law: $$\sigma_1 - \sigma_2 = f_\sigma \frac{N}{t},$$ where $\sigma_1$ and $\sigma_2$ are the principal stresses at a point, $f_\sigma$ material fringe constant (material property), $N$ the fringe order and $t$ the thickness of the structure.
# ###

# %%
% matplotlib notebook
from fem_main_program import launch_fem

U4L1, ReactionForces, VonMises4L1, SXX, SYY, SXY = launch_fem('Polariscope2',MagFac=1)
# Out:
#
#
#
# -----------------------------------------------
# MKM321: Two-Dimensional Linear Finite Element Program
# -----------------------------------------------
# -----------------------------------------------
# Done processing input file :   0.0595 seconds.
# Done assembling K and F    :   9.9687 seconds.
# Done solving system        :   0.5163 seconds.
# Done computing reactions   :   0.0007 seconds.
# Done computing stresses    :   4.5605 seconds.
# Done post-processing stress:   2.4689 seconds.
# Done writing output        :   0.1448 seconds.
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# ...

# %% [markdown]
# # SINGULARITIES
# ## Stress at the tip of a crack as a mesh is made finer
# ## Does the stress converge to some finite value? No, the stress goes to infinity!

# %%
% matplotlib notebook
from fem_main_program import launch_fem

U4L1, ReactionForces, VonMises4L1, SXX, SYY, SXY = launch_fem('crack_q8_10',MagFac=100)
# Out:
#
#
#
# -----------------------------------------------
# MKM321: Two-Dimensional Linear Finite Element Program
# -----------------------------------------------
# -----------------------------------------------
# Done processing input file :   0.0040 seconds.
# Done assembling K and F    :   0.3076 seconds.
# Done solving system        :   0.0048 seconds.
# Done computing reactions   :   0.0007 seconds.
# Done computing stresses    :   0.1090 seconds.
# Done post-processing stress:   0.0800 seconds.
# Done writing output        :   0.0063 seconds.
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
% matplotlib notebook
from fem_main_program import launch_fem

U4L1, ReactionForces, VonMises4L1, SXX, SYY, SXY = launch_fem('crack_q8_20',MagFac=100)
# Out:
#
#
#
# -----------------------------------------------
# MKM321: Two-Dimensional Linear Finite Element Program
# -----------------------------------------------
# -----------------------------------------------
# Done processing input file :   0.0155 seconds.
# Done assembling K and F    :   1.4763 seconds.
# Done solving system        :   0.0462 seconds.
# Done computing reactions   :   0.0005 seconds.
# Done computing stresses    :   0.5191 seconds.
# Done post-processing stress:   0.3479 seconds.
# Done writing output        :   0.0243 seconds.
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
% matplotlib notebook
from fem_main_program import launch_fem

U4L1, ReactionForces, VonMises4L1, SXX, SYY, SXY = launch_fem('crack_q8_50',MagFac=100)
# Out:
#
#
#
# -----------------------------------------------
# MKM321: Two-Dimensional Linear Finite Element Program
# -----------------------------------------------
# -----------------------------------------------
# Done processing input file :   0.1695 seconds.
# Done assembling K and F    :   6.8765 seconds.
# Done solving system        :   0.7957 seconds.
# Done computing reactions   :   0.0009 seconds.
# Done computing stresses    :   4.0370 seconds.
# Done post-processing stress:   1.8601 seconds.
# Done writing output        :   0.0899 seconds.
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# ...
