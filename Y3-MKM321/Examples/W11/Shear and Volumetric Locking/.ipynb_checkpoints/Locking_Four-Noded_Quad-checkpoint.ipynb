# %% [markdown]
# # Beam of length 10mm, height 0.5mm and thickess of 1mm. A moment of 5 Nmm is applied at the edge right edge downwards. The left edge is supported by rollers in vertical direction, i.e. restricting displacement in the horizontal direction. An additional constraint is included to remove any rigid body motions.

# %%
# %matplotlib notebook
from fem_main_program import launch_fem

U, ReactionForces, VonMises, SXX, SYY, SXY = launch_fem('q8_beam_moment_1x1',MagFac=10, IntegrationType='FI')
# Out:
#
#
#
# -----------------------------------------------
# MKM321: Two-Dimensional Linear Finite Element Program
# -----------------------------------------------
# -----------------------------------------------
# Done processing input file :   0.0004 seconds.
# Done assembling K and F    :   0.0080 seconds.
# Done solving system        :   0.0006 seconds.
# Done computing reactions   :   0.0004 seconds.
# Done computing stresses    :   0.0023 seconds.
# Done post-processing stress:   0.0062 seconds.
# Done writing output        :   0.0030 seconds.
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Shear Locking
# ## Four noded quadrilaterial with full integration
# ## Spurious shear when bending is occuring

# %%
# %matplotlib notebook
from fem_main_program import launch_fem

U, ReactionForces, VonMises, SXX, SYY, SXY = launch_fem('q4_beam_moment_3x3',MagFac=10, IntegrationType='FI')
# Out:
#
#
#
# -----------------------------------------------
# MKM321: Two-Dimensional Linear Finite Element Program
# -----------------------------------------------
# -----------------------------------------------
# Done processing input file :   0.0010 seconds.
# Done assembling K and F    :   0.0254 seconds.
# Done solving system        :   0.0005 seconds.
# Done computing reactions   :   0.0004 seconds.
# Done computing stresses    :   0.0209 seconds.
# Done post-processing stress:   0.0144 seconds.
# Done writing output        :   0.0013 seconds.
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
from fem_main_program import launch_fem

U, ReactionForces, VonMises, SXX, SYY, SXY = launch_fem('q4_bar_moment_1x9',MagFac=10, IntegrationType='FI')
# Out:
#
#
#
# -----------------------------------------------
# MKM321: Two-Dimensional Linear Finite Element Program
# -----------------------------------------------
# -----------------------------------------------
# Done processing input file :   0.0012 seconds.
# Done assembling K and F    :   0.0370 seconds.
# Done solving system        :   0.0018 seconds.
# Done computing reactions   :   0.0013 seconds.
# Done computing stresses    :   0.0157 seconds.
# Done post-processing stress:   0.0145 seconds.
# Done writing output        :   0.0062 seconds.
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
from fem_main_program import launch_fem

U, ReactionForces, VonMises, SXX, SYY, SXY = launch_fem('q4_bar_moment_9x1',MagFac=10, IntegrationType='FI')
# Out:
#
#
#
# -----------------------------------------------
# MKM321: Two-Dimensional Linear Finite Element Program
# -----------------------------------------------
# -----------------------------------------------
# Done processing input file :   0.0010 seconds.
# Done assembling K and F    :   0.0318 seconds.
# Done solving system        :   0.0006 seconds.
# Done computing reactions   :   0.0004 seconds.
# Done computing stresses    :   0.0189 seconds.
# Done post-processing stress:   0.0145 seconds.
# Done writing output        :   0.0013 seconds.
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Reduced Intgeration Q4
# ## Attempt to alleviate shear locking - here we uncover other additional issues.

# %%
# %matplotlib notebook
from fem_main_program import launch_fem

U, ReactionForces, VonMises, SXX, SYY, SXY = launch_fem('q4_beam_moment_3x3',MagFac=1E-9, IntegrationType='RI')
# Out:
#
#
#
# -----------------------------------------------
# MKM321: Two-Dimensional Linear Finite Element Program
# -----------------------------------------------
# -----------------------------------------------
# Done processing input file :   0.0008 seconds.
# Done assembling K and F    :   0.0104 seconds.
# Done solving system        :   0.0008 seconds.
# Done computing reactions   :   0.0003 seconds.
# Done computing stresses    :   0.0182 seconds.
# Done post-processing stress:   0.0145 seconds.
# Done writing output        :   0.0026 seconds.
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
from fem_main_program import launch_fem

U, ReactionForces, VonMises, SXX, SYY, SXY = launch_fem('q4_beam_moment_1x9',MagFac=10, IntegrationType='RI')
# Out:
#
#
#
# -----------------------------------------------
# MKM321: Two-Dimensional Linear Finite Element Program
# -----------------------------------------------
# -----------------------------------------------
# Done processing input file :   0.0008 seconds.
# Done assembling K and F    :   0.0104 seconds.
# Done solving system        :   0.0010 seconds.
# Done computing reactions   :   0.0005 seconds.
# Done computing stresses    :   0.0210 seconds.
# Done post-processing stress:   0.0178 seconds.
# Done writing output        :   0.0069 seconds.
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-71541b91fcfd> in <module>()
#       2 from fem_main_program import launch_fem
#       3
# ...

# %%
# %matplotlib notebook
from fem_main_program import launch_fem

U, ReactionForces, VonMises, SXX, SYY, SXY = launch_fem('q4_beam_moment_9x1',MagFac=1E-6, IntegrationType='RI')
# Out:
#
#
#
# -----------------------------------------------
# MKM321: Two-Dimensional Linear Finite Element Program
# -----------------------------------------------
# -----------------------------------------------
# Done processing input file :   0.0019 seconds.
# Done assembling K and F    :   0.0079 seconds.
# Done solving system        :   0.0003 seconds.
# Done computing reactions   :   0.0002 seconds.
# Done computing stresses    :   0.0218 seconds.
# Done post-processing stress:   0.0115 seconds.
# Done writing output        :   0.0010 seconds.
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Volumetric Locking
# ## Four noded quadrilaterial with full integration
# ## Only for plane strain, when the strain energy associated with element deformation becomes artificially high when Poisson's ratio $\nu\rightarrow 0.5$
# ## Reminder $\nu\rightarrow 0.5$ the material approaches an incompressible material
# ## Why only plane strain - as plane stress has freedom to have strain of the plane, whereas in plane strain all strain occurs in the plane.

# %%
from IPython.display import Image
print('Credit to Wikipedia for this Table')
Image("material_proterty_relationships.png")
# Out:
# Credit to Wikipedia for this Table

# %%
import numpy as np
E = 2.1E5
v = 0.49

# Material Matrices
matDpstress = E/(1-v**2)*np.array([[1,v,0],[v,1,0,],[0,0,(1-v)/2]])
matDpstrain = E/((1+v)*(1-2*v))*np.array([[1-v,v,0],[v,1-v,0,],[0,0,(1-2*v)/2]])
print('-----------------------')

matD = matDpstrain

import numpy as np
from elements import Quad4_Stiffness

X = np.array([[0.0, -1],
              [2.0, -1],
              [2.0,  1],
              [0.0,  1]])



Kelem = Quad4_Stiffness(X,matD,1.0)

Eigenvalue, Eigenvector = np.linalg.eig(Kelem)

print('Eight Eigenvalues {}'.format(Eigenvalue))
print('Each column in Eigenvector matrix is an eigenvector')

Mode_Index = 1
Deformation = Eigenvector[:,Mode_Index]
StrainEnergy = 0.5*np.dot(Deformation.transpose(),Kelem).dot(Deformation)

print('Eigenvalues {}'.format(Eigenvalue[Mode_Index]))
print('Check that Eigenvectors are Normalized {}'.format(np.linalg.norm(Deformation)))

import matplotlib.pyplot as plt
Factor = 0.5
NewX = (X[:,0] + Factor*np.take(Deformation,range(0,8,2))).transpose()
NewY = (X[:,1] + Factor*np.take(Deformation,range(1,8,2))).transpose()


plt.figure(100)
plt.plot(X[:,0],X[:,1],'k-o')
plt.plot(NewX, NewY,'r-o')
plt.title('Eigenvalue {} and Strain Energy {}'.format(Eigenvalue[Mode_Index],StrainEnergy))
plt.axis('equal')
plt.legend()
plt.show()
# Out:
# -----------------------
# Eight Eigenvalues [ 7.04697987e+06  1.22147651e+06  1.22147651e+06  1.40939597e+05
#   1.40939597e+05  5.56354707e-10 -2.02466683e-11 -1.97962742e-10]
# Each column in Eigenvector matrix is an eigenvector
# Eigenvalues 1221476.5100671146
# Check that Eigenvectors are Normalized 1.0

# %% [markdown]
# # Beam of length 10mm, height 0.5mm and thickess of 1mm. A point load of 10N at the edge right edge downwards. The left edge is supported by rollers in vertical direction, i.e. restricting displacement in the horizontal direction. An additional constraint is included to remove any rigid body motions.

# %% [markdown]
# # Plane strain with one Q8 element simulation with $\nu=0.49$

# %%
# %matplotlib notebook
from fem_main_program import launch_fem

U, ReactionForces, VonMises, SXX, SYY, SXY = launch_fem('q8_beam_moment_1x1_planestrain',MagFac=10, IntegrationType='FI')

print(U[2*2-1])
# Out:
#
#
#
# -----------------------------------------------
# MKM321: Two-Dimensional Linear Finite Element Program
# -----------------------------------------------
# -----------------------------------------------
# Done processing input file :   0.0005 seconds.
# Done assembling K and F    :   0.0232 seconds.
# Done solving system        :   0.0035 seconds.
# Done computing reactions   :   0.0011 seconds.
# Done computing stresses    :   0.0050 seconds.
# Done post-processing stress:   0.0133 seconds.
# Done writing output        :   0.0074 seconds.
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# [0.08571061]

# %% [markdown]
# # Plane strain simulation with $\nu=0.49$

# %%
# %matplotlib notebook
from fem_main_program import launch_fem

U, ReactionForces, VonMises, SXX, SYY, SXY = launch_fem('q4_beam_moment_1x9_planestrain',MagFac=10, IntegrationType='FI')

print(U[[2*10-1]])
# Out:
#
#
#
# -----------------------------------------------
# MKM321: Two-Dimensional Linear Finite Element Program
# -----------------------------------------------
# -----------------------------------------------
# Done processing input file :   0.0005 seconds.
# Done assembling K and F    :   0.0650 seconds.
# Done solving system        :   0.0007 seconds.
# Done computing reactions   :   0.0005 seconds.
# Done computing stresses    :   0.0191 seconds.
# Done post-processing stress:   0.0153 seconds.
# Done writing output        :   0.0017 seconds.
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# [[6.85628405e-06]]

# %% [markdown]
# # Plane stress simulation with $\nu=0.49$

# %%
# %matplotlib notebook
from fem_main_program import launch_fem

U, ReactionForces, VonMises, SXX, SYY, SXY = launch_fem('q4_beam_moment_1x9_planestress',MagFac=10, IntegrationType='FI')

print(U[[2*10-1]])
# Out:
#
#
#
# -----------------------------------------------
# MKM321: Two-Dimensional Linear Finite Element Program
# -----------------------------------------------
# -----------------------------------------------
# Done processing input file :   0.0005 seconds.
# Done assembling K and F    :   0.0251 seconds.
# Done solving system        :   0.0007 seconds.
# Done computing reactions   :   0.0005 seconds.
# Done computing stresses    :   0.0169 seconds.
# Done post-processing stress:   0.0134 seconds.
# Done writing output        :   0.0010 seconds.
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# [[0.03839606]]
