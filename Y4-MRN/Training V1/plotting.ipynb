# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
RawDataSet = np.load('RawDataToBeSaved.npy', allow_pickle=True)

# %%
print(RawDataSet[0])
# Out:
# [4.78409107e-03 3.27633695e-01 9.46642624e-02 1.29149219e+11
#  4.67067055e+03 2.28339913e-01 2.41240000e+02 5.16480000e+02
#  6.66730000e+02 1.07560000e+03 1.30840000e+03 1.71720000e+03
#  2.15960000e+03 2.47810000e+03]

# %%
OmegaND1 = RawDataSet[:,6]*RawDataSet[:,0]*np.sqrt(RawDataSet[:,4]/RawDataSet[:,3])
AR_A = RawDataSet[:,1]/RawDataSet[:,0]
AR_B = RawDataSet[:,2]/RawDataSet[:,0]
NU = RawDataSet[:,5]

# %%
# Create Figure

fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
 
# Create Plot

ax.scatter3D(AR_A,AR_B,NU)
 
# Show plot

plt.show()
